# %% [markdown]
# # Simulation notebook
# This notebook is used for testing the Zambezi model on the single run *simulation* (not optimization) mode. Three solutions that contain the already optimized policy parameter configurations (with respect to the best of three objectives) are used to run the simulations.

# %%
import os
os.chdir('../src')
from model_zambezi_SIM import ModelZambezi
from utils import utils

# %%
optimized_policy_set = ['best_hydro', 'best_env', 'best_irr']

for policy in optimized_policy_set:
    ZambeziProblem = ModelZambezi(policy_sim=policy)
    policy_input_parameters = utils.loadVector('../decisions/basecase/decisions_'+policy+'.txt',
                                               ZambeziProblem.getNvar)
    ZambeziProblem.evaluate(policy_input_parameters)
# Out:
# objectives: 11.191169669426351 3214070.319504687 1.7957317239236714
# objectives: 18.53075809709479 279.99249597565074 1.7620397049381573
# objectives: 15.1530024997941 772907.2967051559 0.21047396426630507

# %%
from ema_workbench.em_framework.optimization import (epsilon_nondominated, to_problem)

# %% [markdown]
# # Plotting
#
# Below code block will be used to plot some of the actual physical quantities (summary releases across reservoirs, irrigation per catchment, average environmental flows) based on the output files that were produced by above three simulation runs:

# %%
from various_plots import plot_quantities
plot_quantities()

# %% [markdown]
# # Simulation irrigation case

# %%
import os
os.chdir('../src')
from model_zambezi_SIM_irr import ModelZambezi
from utils import utils

# %%
optimized_policy_set = ['best_hydro', 'best_env', 'best_irr']#, 'best_irr2', 'best_irr3', 'best_irr4', 'best_irr5', 'best_irr6', 'best_irr7', 'best_irr8', 'best_irr9']

for policy in optimized_policy_set:
    ZambeziProblem = ModelZambezi(policy_sim=policy)
    policy_input_parameters = utils.loadVector('../testDecisions/irr_decisions_'+policy+'.txt',
                                               ZambeziProblem.getNvar)
    ZambeziProblem.evaluate(policy_input_parameters)
# Out:
# KeyboardInterrupt

# %%
from ema_workbench.em_framework.optimization import (epsilon_nondominated, to_problem)

# %% [markdown]
# # Plotting
#
# Below code block will be used to plot some of the actual physical quantities (summary releases across reservoirs, irrigation per catchment, average environmental flows) based on the output files that were produced by above three (11) simulation runs:

# %%
from various_plots import plot_quantities
#plot_quantities()
